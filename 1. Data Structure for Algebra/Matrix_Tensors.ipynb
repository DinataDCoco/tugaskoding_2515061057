# %%
import numpy as np

# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[57, 75, 39], [43, 77, 89]])
print(X)
# Out:
# [[57 75 39]
#  [43 77 89]]

# %%
# tampilkan ukuran dari matrix X
print(f"Ukuran matrix X : {X.shape}")
# Out:
# Ukuran matrix X : (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
print(X[:, 0])
# Out:
# [57 43]

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
print(X[:, 1])
# Out:
# [75 77]

# %%
import torch as pt

# ulangi soal nomor 1 menggunakan pytorch

# buat matrix X berukuran 2x3
X = pt.tensor([[57, 75, 39], [43, 77, 89]])
print(X)

# tampilkan ukuran dari matrix X
print(f"Ukuran matrix X: {X.shape}")

# tampilkan seluruh elemen dari kolom pertama dari matrix X
print(X[:, 0].tolist())

# tampilkan seluruh elemen dari kolom pertama dari matrix X
print(X[:, 1].tolist())
# Out:
# tensor([[57, 75, 39],
#         [43, 77, 89]])
# Ukuran matrix X: torch.Size([2, 3])
# [57, 43]
# [75, 77]

# %%
import tensorflow as tf

# buat matrix X berukuran 2x3
X = tf.Variable([[57, 75, 39], [43, 77, 89]])
print(X)

# tampilkan ukuran dari matrix X
print(f"Ukuran matrix X: {X.shape}")

# tampilkan seluruh elemen dari kolom pertama dari matrix X
print(X[:, 0].numpy())

# tampilkan seluruh elemen dari kolom kedua dari matrix X
print(X[:, 1].numpy())
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[57, 75, 39],
#        [43, 77, 89]], dtype=int32)>
# Ukuran matrix X: (2, 3)
# [57 43]
# [75 77]
